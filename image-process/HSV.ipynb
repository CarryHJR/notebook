# %% [markdown]
# HSV（Hue, Saturation, Lightness）
# * Hue色调
# * Saturation饱和度，一说深浅，0的话就是灰度
# * Value亮度，色彩的明亮程度，一说明暗,0的话就全黑
#
# RGB比较适合机器理解理解图像，但并不最适合人类的感受，比如我们并认为图像是由RGB三个图像合成的，从人的角度更重要的是色相，明暗，深浅
#
# references:
# * https://zh.wikipedia.org/wiki/HSL和HSV色彩空间
# * https://baike.baidu.com/item/HSV/547122
# * http://blog.csdn.net/timidsmile/article/details/17297811

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

# %%
img = cv2.imread('pictures/nature1.jpeg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## let saturation=0
# s=0即变为灰度图像

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) #convert it to hsv
# hsv[:,:,2] += value
h, s, v = cv2.split(hsv)
# value = 20
s_before = s.copy()
s[:,:]=0
# v[v<value]=0
# v[v>=value] -=value
final_hsv = cv2.merge((h, s, v))

img_decrease_v = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)


plt.figure();
f, axes = plt.subplots(1, 4, figsize=(20, 10));
ax = axes.ravel();
ax[0].hist(h.ravel(), bins=256);
ax[0].set_title('h');
ax[1].hist(s_before.ravel(), bins=256);
ax[1].set_title('s');
ax[2].hist(v.ravel(), bins=256);
ax[2].set_title('v');
ax[3].hist(s.ravel(), bins=256);
ax[3].set_title('s_after');
# plt.imshow(cv2.cvtColor(img_decrease_v, cv2.COLOR_BGR2RGB))
plt.figure();
f, axes = plt.subplots(1, 2, figsize=(20, 10));
ax = axes.ravel();
ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB));
ax[1].imshow(cv2.cvtColor(img_decrease_v, cv2.COLOR_BGR2RGB));

# %% [markdown]
# ## let v=0
# value=0就是全黑了

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) #convert it to hsv
# hsv[:,:,2] += value
h, s, v = cv2.split(hsv)
# value = 20
v_before = v.copy()
v[:,:]=0
# v[v<value]=0
# v[v>=value] -=value
final_hsv = cv2.merge((h, s, v))

img_decrease_v = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)


plt.figure();
f, axes = plt.subplots(1, 4, figsize=(20, 10));
ax = axes.ravel();
ax[0].hist(h.ravel(), bins=256);
ax[0].set_title('h');
ax[1].hist(s_before.ravel(), bins=256);
ax[1].set_title('s');
ax[2].hist(v_before.ravel(), bins=256);
ax[2].set_title('v');
ax[3].hist(v.ravel(), bins=256);
ax[3].set_title('s_after');
# plt.imshow(cv2.cvtColor(img_decrease_v, cv2.COLOR_BGR2RGB))
plt.figure();
f, axes = plt.subplots(1, 2, figsize=(20, 10));
ax = axes.ravel();
ax[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB));
ax[1].imshow(cv2.cvtColor(img_decrease_v, cv2.COLOR_BGR2RGB));
